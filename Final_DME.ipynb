# %% [markdown]
# # Фінальний проект "Населення"
#
# ### Виконує:
#
# #### Онищенко Богдан \ Onyshchenko Bohdan \ vumenira

# %%
import pandas as pd
import altair as alt

# %% [markdown]
# ## Частина 1: Підготовка даних

# %%
people_1778 = pd.read_csv("2.2_Дунаєць_1778.xlsx - База.csv")

people_1897 = pd.read_csv("2.1_Дунаєць.xlsx - База людей.csv")

# %%
people_1778.columns = people_1778.iloc[2].values
people_1778 = people_1778.iloc[3:].reset_index(drop=True)
people_1778.columns.values[0] = "Аркуш"
people_1778.columns.values[4] = "Чоловіки наскрізне"
people_1778.columns.values[5] = "Жінки наскрізне"
people_1778.columns.values[6] = "Чоловіки джерело"
people_1778.columns.values[7] = "Жінки джерело"
people_1778 = people_1778.set_index("ID наскрізна", drop=True)

people_1778
# Out:
#              Аркуш ID домогосподарство Двори джерело Чоловіки наскрізне  \
# ID наскрізна
# 1              445                   1             1                  1
# 2              NaN                 NaN           NaN                NaN
# 3              NaN                 NaN           NaN                NaN
# 4              NaN                 NaN           NaN                  2
# 5              NaN                 NaN           NaN                  2
# ...            ...                 ...           ...                ...
# 1593           NaN                 104            12                824
# 1594           NaN                 NaN           NaN                NaN
# 1595           NaN                 105            13                825
# 1596           NaN                 NaN           NaN                NaN
# 1597           NaN                 NaN           NaN                826
#
#              Жінки наскрізне Чоловіки джерело Жінки джерело         Імʼя  \
# ID наскрізна
# 1                        NaN                1           NaN        Федор
# 2                          1              NaN             1      Варвара
# 3                          2              NaN             2         Анна
# 4                        NaN                2           NaN      Тимофей
# 5                        NaN                2           NaN  Пантелеймон
# ...                      ...              ...           ...          ...
# 1593                     NaN              236           NaN      Леонтий
# 1594                     770              NaN           222      Мотрона
# 1595                     NaN              237           NaN      Герасим
# 1596                     771              NaN           223       Агафия
# 1597                     NaN              238           NaN       Лукьян
#
#              По-батькові   Прізвище              Родиний статус Категорія  \
# ID наскрізна
# 1             Кондратьев  Лукашевич                    господар   nuclear
# 2                 Симева        NaN                        жена       NaN
# 3                    NaN        NaN                        дочь       NaN
# 4                    NaN        NaN                         сын       NaN
# 5                    NaN        NaN                         сын       NaN
# ...                  ...        ...                         ...       ...
# 1593           Афанасиев        NaN  двоюродный брат Александра   nuclear
# 1594           Михайлова        NaN                    жена его       NaN
# 1595               Фомик     Мерник                    господар   nuclear
# 1596           Максимова        NaN                    жена его       NaN
# 1597                 NaN        NaN                         NaN       NaN
#
#              Клас Соціальний статус Вік Був на сповіді Не був  \
# ID наскрізна
# 1              3b          духовные  44              х    NaN
# 2             NaN          духовные  35              х    NaN
# 3             NaN          духовные  17              х    NaN
# 4             NaN          духовные  15              х    NaN
# 5             NaN          духовные  14              х    NaN
# ...           ...               ...  ..            ...    ...
# 1593           3a        бездворные  25              х    NaN
# 1594          NaN        бездворные  22              х    NaN
# 1595           3b        бездворные  43              х    NaN
# 1596          NaN        бездворные  42              х    NaN
# 1597          NaN        бездворные  14              х    NaN
#
#              Не був за малолітством
# ID наскрізна
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# ...                             ...
# 1593                            NaN
# 1594                            NaN
# 1595                            NaN
# 1596                            NaN
# 1597                            NaN
#
# [1597 rows x 18 columns]

# %%
people_1897
# Out:
#                                       Кто заполнял базу  ID строки в базе  \
# 0                                              Podhorna               1.0
# 1                                              Podhorna               2.0
# 2                                              Podhorna               3.0
# 3                                              Podhorna               4.0
# 4                                              Podhorna               5.0
# ...                                                 ...               ...
# 1547                                           Podhorna            1548.0
# 1548                                                NaN               NaN
# 1549                                                NaN               NaN
# 1550                                                NaN               NaN
# 1551  * - В оригінальному джерелі ячейка "мова" була...               NaN
#
#                                List ID  \
# 0         F.132.Op.1.Spr.1343. Арк.1-2
# 1         F.132.Op.1.Spr.1343. Арк.1-2
# 2         F.132.Op.1.Spr.1343. Арк.1-2
# 3         F.132.Op.1.Spr.1343. Арк.1-2
# 4         F.132.Op.1.Spr.1343. Арк.1-2
# ...                                ...
# 1547  F.132.Op.1.Spr.1343. Арк.550-551
# 1548                               NaN
# 1549                               NaN
# 1550                               NaN
# 1551                               NaN
#
#                                                    Link  ID Домохозяйствао  \
# 0     https://www.familysearch.org/ark:/61903/3:1:3Q...                1.0
# 1     https://www.familysearch.org/ark:/61903/3:1:3Q...                1.0
# 2     https://www.familysearch.org/ark:/61903/3:1:3Q...                1.0
# 3     https://www.familysearch.org/ark:/61903/3:1:3Q...                1.0
# 4     https://www.familysearch.org/ark:/61903/3:1:3Q...                1.0
# ...                                                 ...                ...
# 1547  https://www.familysearch.org/ark:/61903/3:1:3Q...              261.0
# 1548                                                NaN                NaN
# 1549                                                NaN                NaN
# 1550                                                NaN                NaN
# 1551                                                NaN                NaN
#
#       ID жилец                               ФИО  Пол  \
# 0          1.0  Krasovskij Pantelejmon Ivanovich    m
# 1          2.0   Krasovskaya Stefanida Artemieva    f
# 2          3.0   Krasovskaya Anna Pantelejmonova    f
# 3          4.0   Krasovskij Stefan Pantelejmonov    m
# 4          5.0         Krasovskij Ivan Kondratov    m
# ...        ...                               ...  ...
# 1547       6.0          Gricunov Mikhail Sergeev    m
# 1548       NaN                               NaN  NaN
# 1549       NaN                               NaN  NaN
# 1550       NaN                               NaN  NaN
# 1551       NaN                               NaN  NaN
#
#      Глава хозяйства и глава семьи Возраст  ...  \
# 0                          husband      32  ...
# 1                             wife      28  ...
# 2                         daughter       5  ...
# 3                              son       1  ...
# 4                           father      70  ...
# ...                            ...     ...  ...
# 1547                           son       3  ...
# 1548                           NaN     NaN  ...
# 1549                           NaN     NaN  ...
# 1550                           NaN     NaN  ...
# 1551                           NaN     NaN  ...
#
#      Здесь ли обыкновенно проживает Отметка об отсуствии  Вероисповедание  \
# 0                                 1                  NaN         orthodox
# 1                                 1                  NaN         orthodox
# 2                                 1                  NaN         orthodox
# 3                                 1                  NaN         orthodox
# 4                                 1                  NaN         orthodox
# ...                             ...                  ...              ...
# 1547                              1                  NaN         orthodox
# 1548                            NaN                  NaN              NaN
# 1549                            NaN                  NaN              NaN
# 1550                            NaN                  NaN              NaN
# 1551                            NaN                  NaN              NaN
#
#      Родной язык Умеет ли читать      Обучение    Профессия главное  \
# 0            ukr             1.0  rural school               farmer
# 1            ukr             0.0           NaN  farmer with husband
# 2            ukr             0.0           NaN          with father
# 3           ukrm             0.0           NaN          with father
# 4            ukr             0.0           NaN             with son
# ...          ...             ...           ...                  ...
# 1547         ukr             0.0           NaN          with father
# 1548         NaN             NaN           NaN                  NaN
# 1549         NaN             NaN           NaN                  NaN
# 1550         NaN             NaN           NaN                  NaN
# 1551         NaN             NaN           NaN                  NaN
#
#      Профессия вспомогательное Положение по воинской повинности  \
# 0                          NaN              Nizhnij chin zapasu
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
# ...                        ...                              ...
# 1547                       NaN                              NaN
# 1548                       NaN                              NaN
# 1549                       NaN                              NaN
# 1550                       NaN                              NaN
# 1551                       NaN                              NaN
#
#                             Примітки
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4     Slep na oba hlaza 10 let nazad
# ...                              ...
# 1547                             NaN
# 1548                             NaN
# 1549                             NaN
# 1550                             NaN
# 1551                             NaN
#
# [1552 rows x 25 columns]
